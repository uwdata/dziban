# %%
from dziban.mkiv import Chart
from vega_datasets import data

# %%
movies = data('movies')

# %%
prior = Chart(movies).field('IMDB_Rating', 'Rotten_Tomatoes_Rating')
prior

# %%
anchor = prior.anchor().field('Worldwide_Gross', bin=True)
anchor
# Out:
# [{'$schema': 'https://vega.github.io/schema/vega-lite/v3.json', 'data': {'url': 'data/cars.json'}, 'mark': 'point', 'encoding': {'x': {'type': 'quantitative', 'field': 'IMDB_Rating', 'scale': {'zero': True}}, 'y': {'type': 'quantitative', 'field': 'Rotten_Tomatoes_Rating', 'scale': {'zero': True}}, 'size': {'type': 'quantitative', 'field': 'Worldwide_Gross', 'bin': True, 'scale': {'zero': True}}}}, {'$schema': 'https://vega.github.io/schema/vega-lite/v3.json', 'data': {'url': 'data/cars.json'}, 'mark': 'text', 'encoding': {'x': {'type': 'quantitative', 'field': 'IMDB_Rating', 'scale': {'zero': True}}, 'y': {'type': 'quantitative', 'field': 'Rotten_Tomatoes_Rating', 'scale': {'zero': True}}, 'text': {'type': 'ordinal', 'field': 'Worldwide_Gross', 'bin': True}}}, {'$schema': 'https://vega.github.io/schema/vega-lite/v3.json', 'data': {'url': 'data/cars.json'}, 'mark': 'text', 'encoding': {'x': {'type': 'quantitative', 'field': 'IMDB_Rating', 'scale': {'zero': True}}, 'y': {'type': 'quan
# ...

# %%
anchor._get_stats()
# Out:
# {'draco_score': 31,
#  'norm_draco_score': 0.0,
#  'draco_rank': 0,
#  'draco_of': 50,
#  'graphscape_score': 0,
#  'norm_graphscape_score': -1.0222222222222221,
#  'graphscape_rank': None,
#  'graphscape_of': 50}
