# %%
from dziban.mkiv import Chart
from vega_datasets import data

# %%
cars = data('cars')
gapminder = data('gapminder')

# %%
base = Chart(data('cars')).field('Acceleration', 'Horsepower')
base
# Out:
# dict_items([])

# %%
c1 = base.field(aggregate='count')
c1
# Out:
# dict_items([])

# %%
c1.field(aggregate=None)._encodings
# Out:
# dict_items([('aggregate', None)])
# hit
# [False, False, False, False]

# %%
c2 = c1.field('Acceleration', bin=True).anchor_on(c1)
c2._get_vegalite()
# Out:
# dict_items([('bin', True)])
# {'$schema': 'https://vega.github.io/schema/vega-lite/v3.json',
#  'data': {'url': 'data/cars.json'},
#  'mark': 'point',
#  'encoding': {'size': {'type': 'quantitative',
#    'aggregate': 'count',
#    'scale': {'zero': True}},
#   'y': {'type': 'quantitative', 'field': 'Acceleration', 'bin': True},
#   'x': {'type': 'quantitative', 'field': 'Horsepower', 'bin': True}}}

# %%
c2.mark('point').anchor_on(c2)._get_full_query()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-4c9eef134043> in <module>
# ----> 1 c2.mark('point').anchor_on(c2)._get_full_query()
#
# ~/dziban/dziban/mkiv/chart.py in _get_full_query(self)
#     107   def _get_full_query(self):
#     108     partial = self._get_asp_partial()
# --> 109     anchor = self._get_anchor_asp()
#     110
#     111     query = partial + anchor
#
# ~/dziban/dziban/mkiv/chart.py in _get_anchor_asp(self)
#     230     REGEX = re.compile(r'(\w+)\(([\w\.\"\/]+)(,([\w\"\.]+))?(,([\w\.\"]+))?\)')
#     231
# --> 232     anchor_complete = self._anchor._get_asp_complete()
#     233     asp = ['base({0}).'.format(self._anchor._name)] + anchor_complete
#     234
#
# ~/dziban/dziban/mkiv/chart.py in _get_asp_complete(self)
#     199
#     200   def _get_asp_complete(self):
# --> 201     sol = self._get_draco_sol()
# ...

# %%
base.field('Horsepower')._get_draco_score()

# %%
base.field('Horsepower').anchor_on(base)
