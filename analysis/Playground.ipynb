# %%
from dziban.mkiv import Chart
from vega_datasets import data

# %%
cars = data('cars')
gapminder = data('gapminder')

# %%
base = Chart(data('cars')).field('Origin', 'Acceleration')

# %%
base.field('Horsepower')._get_graphscape_rank(base)

# %%
gapminder1 = Chart(gapminder).field('country', 'pop')
gapminder1

# %%
gapminder1.mark('point')._get_graphscape_rank(gapminder1)
# Out:
# 13
