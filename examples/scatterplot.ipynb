# %% [markdown]
# # ScatterPlot

# %%
from dziban.viz import Viz
from vega_datasets import data
from vega import VegaLite

# %% [markdown]
# ## Strict

# %%
v = Viz().mark_point().encoding(
        x = { 'field': 'Horsepower', 'type': 'quantitative' },
        y = { 'field': 'Acceleration', 'type': 'quantitative' }
).strict()

spec = v.build()

# %%
a = VegaLite(spec, data.cars())

# %% [markdown]
# ## Partial

# %%
v = Viz(data.cars()).mark_point().encoding(
        'Horsepower',
        'Miles_per_Gallon'
).build()

# %%
VegaLite(v.result.as_vl(0), data.cars())

# %%
print('\n'.join(v.result.props))
# Out:
# visualization(v1).
# encoding(v1,e0).
# encoding(v1,e1).
# mark(v1,point).
# field(v1,e0,"Horsepower").
# field(v1,e1,"Miles_per_Gallon").
# type(v1,e0,quantitative).
# type(v1,e1,quantitative).
# channel(v1,e0,y).
# channel(v1,e1,x).
# zero(v1,e0).
# zero(v1,e1).

# %%
v2 = v.mark_point().build()
# Out:
# visualization(v1).
# encoding(v1,e0).
# encoding(v1,e1).
# mark(v1,point).
# field(v1,e0,"Horsepower").
# field(v1,e1,"Miles_per_Gallon").
# type(v1,e0,quantitative).
# type(v1,e1,quantitative).
# channel(v1,e0,y).
# channel(v1,e1,x).
# zero(v1,e0).
# zero(v1,e1).
# :- not { encoding(v1,_) } = 2.
# :- not { field(v1,_,_) } = 2.
# :- not { type(v1,_,_) } = 2.
# :- not { channel(v1,_,_) } = 2.
# :- not { zero(v1,_) } = 2.

# %%
v2.violations
# Out:
# defaultdict(int,
#             {'encoding': 4,
#              'encoding_field': 4,
#              'type_q': 4,
#              'c_c_point': 2,
#              'continuous_x': 2,
#              'continuous_y': 2})

# %%
VegaLite(v2.as_vl(1), data.cars())

# %%
print('\n'.join(filter(lambda x : 'v2' in x,v2.props)))
# Out:
# visualization(v2).
# encoding(v2,e0).
# encoding(v2,e1).
# mark(v2,point).
# field(v2,e0,"Horsepower").
# field(v2,e1,"Miles_per_Gallon").
# type(v2,e0,quantitative).
# type(v2,e1,quantitative).
# channel(v2,e0,y).
# channel(v2,e1,x).
# zero(v2,e0).
# zero(v2,e1).
