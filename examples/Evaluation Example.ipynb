# %%
import pandas as pd
import dziban as dzi
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-46fe5962de69> in <module>
#       1 import pandas as pd
# ----> 2 import dziban as dzi
#
# ModuleNotFoundError: No module named 'dziban'

# %%
df = pd.read_csv('sunshine.csv')

# %%
# Out:
#              city         lon        lat month  monthnum  sunshine
# 0         Seattle -122.335167  47.608013   Jan         0        69
# 1         Seattle -122.335167  47.608013   Feb         1       108
# 2         Seattle -122.335167  47.608013   Mar         2       178
# 3         Seattle -122.335167  47.608013   Apr         3       207
# 4         Seattle -122.335167  47.608013   May         4       253
# 5         Seattle -122.335167  47.608013   Jun         5       268
# 6         Seattle -122.335167  47.608013   Jul         6       312
# 7         Seattle -122.335167  47.608013   Aug         7       281
# 8         Seattle -122.335167  47.608013   Sep         8       221
# 9         Seattle -122.335167  47.608013   Oct         9       142
# 10        Seattle -122.335167  47.608013   Nov        10        72
# 11        Seattle -122.335167  47.608013   Dec        11        52
# 12        Chicago  -87.623177  41.881832   Jan         0       135
# ...
